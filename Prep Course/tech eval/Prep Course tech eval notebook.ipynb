# %%
import random

# %%
sample1 = random.sample(list(range(1,50)), 4)
sample2 = random.sample(list(range(1,25)), 1)
# Out:
# [39, 32, 47, 20]

# %%
1/50*1/49*1/48*1/47*1/25

# %%
file = 'plane_crashes_data.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(file)

# %%
df.describe()
# Out:
#              month         year       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000
# mean      6.554079  1981.927279    35.817276    25.816537
# std       3.532468    16.709136    54.306779    42.599461
# min       1.000000  1950.000000     0.000000     0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000
# 50%       7.000000  1983.000000    15.000000     9.000000
# 75%      10.000000  1997.000000    44.000000    29.000000
# max      12.000000  2009.000000   644.000000   583.000000

# %%
subset = df.fatalities[(df.year >=1980) & (df.year<= 2009)]

# %%
subset.describe()
# Out:
# count    1469.000000
# mean       24.932607
# std        45.951019
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        22.000000
# max       520.000000
# Name: fatalities, dtype: float64

# %%
months = df.groupby(['month'])

# %%
months.describe()
# Out:
#       aboard                                                     fatalities  \
#        count       mean        std  min  25%   50%    75%    max      count
# month
# 1      255.0  28.745098  38.833504  1.0  4.0  15.0  35.00  213.0      255.0
# 2      209.0  37.976077  55.470144  1.0  4.0  15.0  49.00  356.0      209.0
# 3      251.0  31.729084  56.190518  1.0  5.0  14.0  38.00  644.0      251.0
# 4      204.0  30.715686  46.521117  1.0  5.0  15.5  31.25  330.0      204.0
# 5      181.0  32.149171  45.389975  1.0  5.0  13.0  37.00  271.0      181.0
# 6      202.0  37.767327  51.884394  1.0  5.0  18.0  49.25  329.0      202.0
# 7      234.0  40.051282  64.126129  1.0  5.0  14.0  49.00  517.0      234.0
# 8      239.0  40.372385  65.210708  1.0  4.0  15.0  46.50  524.0      239.0
# 9      228.0  39.868421  56.895842  0.0  6.0  16.5  53.25  394.0      228.0
# 10     224.0  28.758929  39.606754  1.0  4.0  11.0  34.00  226.0      224.0
# ...

# %%
# %matplotlib inline

# %%
df[(df.fatalities >=1)].count()
# Out:
# month         2660
# hour          2660
# year          2660
# location      2657
# operator      2658
# route         2279
# type          2659
# aboard        2660
# fatalities    2660
# summary       2647
# dtype: int64

# %%
2660/len(df)
# Out:
# 0.9819121447028424

# %%
df['perc_fatalities'] = df.fatalities/df.aboard

# %%
df.perc_fatalities.mean()
# Out:
# 0.82313192235105637

# %%
24.93
January
583
98
82
